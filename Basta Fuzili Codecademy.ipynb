# %%
brunch_item={
  'pancakes': 7.50, 'waffles': 9.00, 'burger': 11.00, 'home fries': 4.50, 'coffee': 1.50, 'espresso': 3.00, 'tea': 1.00, 'mimosa': 10.50, 'orange juice': 3.50
}

early_bird_item={
  'salumeria plate': 8.00, 'salad and breadsticks (serves 2, no refills)': 14.00, 'pizza with quattro formaggi': 9.00, 'duck ragu': 17.50, 'mushroom ravioli (vegan)': 13.50, 'coffee': 1.50, 'espresso': 3.00,
}

dinner_item={
  'crostini with eggplant caponata': 13.00, 'ceaser salad': 16.00, 'pizza with quattro formaggi': 11.00, 'duck ragu': 19.50, 'mushroom ravioli (vegan)': 13.50, 'coffee': 2.00, 'espresso': 3.00,
}

kids_item={
  'chicken nuggets': 6.50, 'fusilli with wild mushrooms': 12.00, 'apple juice': 3.00
}

arepas_menu_item={
  'arepa pabellon': 7.00, 'pernil arepa': 8.50, 'guayanes arepa': 8.00, 'jamon arepa': 7.50
}

class Menu:
    def __init__(self, name, items, start_time, end_time):
        self.name=name
        self.items=items
        self.start_time=start_time
        self.end_time=end_time
    def __repr__(self):
        return "{name} menu available from {start} to {end}".format(name=self.name, start=str(self.start_time), end=str(self.end_time))

    def calculate_bill(self,purchased_items):
        total_bill=0
        for key,value in self.items.items():
            for i in purchased_items:
                if key==i:
                    total_bill+=value
        return total_bill
    def menu(self):
        for key,value in self.items.items():
            print( "You can order {item}. Price is {price}".format(item=key,price=value))
  
class Franchise:
  def __init__(self,adress,menus):
    self.adress=adress
    self.menus=menus
  def __repr__(self):
    return "We located at{adress}".format(adress=self.adress)
  def available_menus(self, time):
    available_menu = []
    for menu in self.menus:
        if time >= menu.start_time and time < menu.end_time:
            available_menu.append(menu)
    for i in self.menus:
        for key,value in i.items.items():
            print("You can order {name}. Price is {price}".format(name=key,price=value))
    return(available_menu)

class Business:
  def __init__(self,name,franchises):
    self.name=name
    self.franchises=franchises
  
brunch=Menu("brunch",brunch_item,11,16)

early_bird=Menu("early_bird",early_bird_item,3,6)

dinner=Menu("dinner",dinner_item,17,23)

kids=Menu("kids",kids_item,11,21)


arepas_menu=Menu("Arepas Menu",arepas_menu_item,10,20)

flagship_store=Franchise("1232 West End Road",[brunch,early_bird,dinner,kids])

new_installment=Franchise("12 East Mulberry Street",[brunch,early_bird,dinner,kids])

arepas_place=Franchise("189 Fitzgerald Avenue",[arepas_menu])

franchises_Basta=[]
franchises_Basta.append(flagship_store)
franchises_Basta.append(new_installment)

franchises_arepa=[]
franchises_arepa.append(arepas_place)

business=Business("Basta Fazoolin' with my Heart",franchises_Basta)
Arepa_business=Business("Take a' Arepa",franchises_arepa)

print(arepas_place.available_menus(12))
# Out:
# You can order arepa pabellon. Price is 7.0
# You can order pernil arepa. Price is 8.5
# You can order guayanes arepa. Price is 8.0
# You can order jamon arepa. Price is 7.5
# [Arepas Menu menu available from 10 to 20]
